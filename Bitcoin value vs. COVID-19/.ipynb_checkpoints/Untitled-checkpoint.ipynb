# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Historical data about BTC price in USD$

# %%
btc_dataset = pd.read_csv("BTC-USD.csv")
btc_dataset.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2019-03-16  3963.900146  4077.036377  3961.657471  4048.725830
# 1  2019-03-17  4047.719482  4054.122070  4006.411133  4025.229004
# 2  2019-03-18  4029.968506  4071.556641  4009.117188  4032.507324
# 3  2019-03-19  4032.691895  4082.216064  4023.812500  4071.190186
# 4  2019-03-20  4070.793945  4089.461914  4031.110840  4087.476318
#
#      Adj Close       Volume
# 0  4048.725830   9856166973
# 1  4025.229004   8221625399
# 2  4032.507324   9646954186
# 3  4071.190186   9344919956
# 4  4087.476318  10175916388

# %%
btc_filtered = btc_dataset[(btc_dataset.Date >= '2019-31-12') & (btc_dataset.Date <= '2020-16-03')][["Date", "Open"]]
btc_filtered
# Out:
#            Date         Open
# 291  2020-01-01  7194.892090
# 292  2020-01-02  7202.551270
# 293  2020-01-03  6984.428711
# 294  2020-01-04  7345.375488
# 295  2020-01-05  7410.451660
# ..          ...          ...
# 362  2020-03-12  7913.616211
# 363  2020-03-13  5017.831055
# 364  2020-03-14  5573.077637
# 365  2020-03-15  5201.066895
# 366  2020-03-16  5334.256348
#
# [76 rows x 2 columns]

# %%
import datetime as dt
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

dates = btc_filtered.Date
x_btc = [dt.datetime.strptime(d,'%Y-%m-%d').date() for d in dates]
y_btc = btc_filtered.Open

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval = 10))
plt.plot(x_btc,y_btc)

plt.gcf().autofmt_xdate()

# %% [markdown]
# ### Historical data about COVID-19 cases worldwide

# %%
covid_dataset = pd.read_excel('COVID-19.xls')
covid_dataset.head()
# Out:
#      DateRep   CountryExp  NewConfCases  NewDeaths GeoId Gaul1Nuts1  \
# 0 2020-03-16  Afghanistan             6        0.0    AF        NaN
# 1 2020-03-15  Afghanistan             3        0.0    AF        NaN
# 2 2020-03-11  Afghanistan             3        0.0    AF        NaN
# 3 2020-03-08  Afghanistan             3        0.0    AF        NaN
# 4 2020-03-02  Afghanistan             0        0.0    AF        NaN
#
#            EU
# 0  Non-EU/EEA
# 1  Non-EU/EEA
# 2  Non-EU/EEA
# 3  Non-EU/EEA
# 4  Non-EU/EEA

# %%
grouped_covid = covid_dataset.groupby("DateRep").sum()
grouped_covid.head(10)
# Out:
#             NewConfCases  NewDeaths
# DateRep
# 2019-12-31            27        0.0
# 2020-01-01             0        0.0
# 2020-01-02             0        0.0
# 2020-01-03            17        0.0
# 2020-01-04             0        0.0
# 2020-01-05            15        0.0
# 2020-01-06             0        0.0
# 2020-01-07             0        0.0
# 2020-01-08             0        0.0
# 2020-01-09             0        0.0

# %%
y = []
i = 0
j = 0

for i in range(len(grouped_covid.NewConfCases)):
    j = 0
    val = 0
    while(j <= i):
        val+=grouped_covid.NewConfCases[j]
        j+=1
    y.append(val)

# %%
import datetime as dt
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

dates = grouped_covid.index
x = [dt.datetime.strptime(str(d.date()),'%Y-%m-%d').date() for d in dates]

plt.figure(figsize=(40,10))
fig = plt.figure()
fig, (axs1, axs2) = plt.subplots(1, 2, figsize = (15, 8))

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval = 10))

axs1.plot_date(x, y, 'b-')
axs1.title.set_text('Cases of COVID-19 worldwide')


axs2.plot_date(x_btc, y_btc, 'r-')
axs2.title.set_text('Bitcoin price in USD')


fig.autofmt_xdate()

plt.show()
