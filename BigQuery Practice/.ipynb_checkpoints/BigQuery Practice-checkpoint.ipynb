# %%
from google.cloud import bigquery
import pandas as pd

# %%
client = bigquery.Client()

# %%
dataset_ref = client.dataset("openaq", project = "bigquery-public-data")

# %%
dataset = client.get_dataset(dataset_ref)

# %%
tables = list(client.list_tables(dataset))

# %%
for table in tables:
    print (table.table_id)
# Out:
# global_air_quality

# %%
table_ref = dataset_ref.table("global_air_quality")
table = client.get_table(table_ref)

# %%
table.schema
# Out:
# [SchemaField('location', 'STRING', 'NULLABLE', 'Location where data was measured', ()),
#  SchemaField('city', 'STRING', 'NULLABLE', 'City containing location', ()),
#  SchemaField('country', 'STRING', 'NULLABLE', 'Country containing measurement in 2 letter ISO code', ()),
#  SchemaField('pollutant', 'STRING', 'NULLABLE', 'Name of the Pollutant being measured. Allowed values: PM25, PM10, SO2, NO2, O3, CO, BC', ()),
#  SchemaField('value', 'FLOAT', 'NULLABLE', 'Latest measured value for the pollutant', ()),
#  SchemaField('timestamp', 'TIMESTAMP', 'NULLABLE', 'The datetime at which the pollutant was measured, in ISO 8601 format', ()),
#  SchemaField('unit', 'STRING', 'NULLABLE', 'The unit the value was measured in coded by UCUM Code', ()),
#  SchemaField('source_name', 'STRING', 'NULLABLE', 'Name of the source of the data', ()),
#  SchemaField('latitude', 'FLOAT', 'NULLABLE', 'Latitude in decimal degrees. Precision >3 decimal points.', ()),
#  SchemaField('longitude', 'FLOAT', 'NULLABLE', 'Longitude in decimal degrees. Precision >3 decimal points.', ()),
#  SchemaField('averaged_over_in_hours', 'FLOAT', 'NULLABLE', 'The number of hours the value was averaged over.', ())]

# %%
client.list_rows(table, max_results = 5).to_dataframe()
# Out:
#                         location       city country pollutant   value  \
# 0  BTM Layout, Bengaluru - KSPCB  Bengaluru      IN        co  910.00
# 1  BTM Layout, Bengaluru - KSPCB  Bengaluru      IN       no2  131.87
# 2  BTM Layout, Bengaluru - KSPCB  Bengaluru      IN        o3   15.57
# 3  BTM Layout, Bengaluru - KSPCB  Bengaluru      IN      pm25   45.62
# 4  BTM Layout, Bengaluru - KSPCB  Bengaluru      IN       so2    4.49
#
#                   timestamp   unit source_name   latitude  longitude  \
# 0 2018-02-22 03:00:00+00:00  µg/m³        CPCB  12.912811   77.60922
# 1 2018-02-22 03:00:00+00:00  µg/m³        CPCB  12.912811   77.60922
# 2 2018-02-22 03:00:00+00:00  µg/m³        CPCB  12.912811   77.60922
# 3 2018-02-22 03:00:00+00:00  µg/m³        CPCB  12.912811   77.60922
# 4 2018-02-22 03:00:00+00:00  µg/m³        CPCB  12.912811   77.60922
#
#    averaged_over_in_hours
# 0                    0.25
# 1                    0.25
# 2                    0.25
# 3                    0.25
# 4                    0.25

# %% [markdown]
# ### Pollutants that are measured in Bosnia and Herzegovina

# %%
query_job = client.query("""
    SELECT DISTINCT pollutant
    FROM `bigquery-public-data.openaq.global_air_quality`
    WHERE country = 'BA' AND CAST(timestamp as date) = CAST("2020-01-19" as date)
    """)

# %%
results = query_job.result()

# %%
results.to_dataframe()
# Out:
#   pollutant
# 0      pm25
# 1        co
# 2       no2
# 3       so2
# 4        o3

# %% [markdown]
# ### I assumed that all those location are divided in some regions

# %%
query_job = client.query("""
    SELECT DISTINCT source_name
    FROM `bigquery-public-data.openaq.global_air_quality`
    WHERE country = "BA" 
    """)

# %%
results = query_job.result()

# %%
results.to_dataframe()
# Out:
#         source_name
# 0            Bosnia
# 1           Bosnia2
# 2          Sarajevo
# 3  Bosnia_Tuzlanski

# %% [markdown]
# ### Let's see all those locations for every region

# %%
query_job = client.query("""
    SELECT DISTINCT location
    FROM `bigquery-public-data.openaq.global_air_quality`
    WHERE country = "BA" AND source_name = "Bosnia_Tuzlanski"
    """)

# %%
results = query_job.result()

# %%
tuzla = results.to_dataframe()

# %%
tuzla.columns = ["Bosnia_Tuzlanski"]
tuzla
# Out:
#   Bosnia_Tuzlanski
# 0         Živinice
# 1          Bukinje
# 2              BKC
# 3          Lukavac
# 4            Skver

# %%
query_job = client.query("""
    SELECT DISTINCT location
    FROM `bigquery-public-data.openaq.global_air_quality`
    WHERE country = "BA" AND source_name = "Bosnia"
    """)

# %%
results = query_job.result()

# %%
result = results.to_dataframe()

# %%
result.columns = ["Bosnia"]
result
# Out:
#              Bosnia
# 0          Rasadnik
# 1        Ivan Sedlo
# 2  mobilna (Ilidža)
# 3             Otoka
# 4         Vijećnica
# 5             Brist
# 6           Harmani

# %%
query_job = client.query("""
    SELECT DISTINCT location
    FROM `bigquery-public-data.openaq.global_air_quality`
    WHERE country = "BA" AND source_name = "Bosnia2"
    """)

# %%
results = query_job.result()

# %%
result = results.to_dataframe()

# %%
result.columns = ["Bosnia2"]
result
# Out:
#       Bosnia2
# 0    Rasadnik
# 1   IvanSedlo
# 2      Ilidža
# 3       Otoka
# 4   Vijećnica
# 5     Bjelave
# 6      Ilijaš
# 7       Doboj
# 8    Radakovo
# 9       Brist
# 10     Tetovo
# 11    Harmani

# %% [markdown]
# ##### Bosnia2 contains the same locations as Bosnia except that Bosnia has mobilna(ilidza). So, I am going to analyze all those locations from Bosnia2 and just one from Bosnia (mobilna Ilidza).
#
# After analysis below you can see that source_names "Bosnia" and "Bosnia2" do not measure data now.
# All those data in the dataset was from previous years(2018, 2019). So I am going to ignore those values, as I want to plot the newest data.

# %%
query_job = client.query("""
    SELECT *
    FROM `bigquery-public-data.openaq.global_air_quality`
    WHERE source_name = "Bosnia2"
""")

# %%
results = query_job.result()
result = results.to_dataframe()
result
# Out:
#      location      city country pollutant   value                 timestamp  \
# 0      Centar    MK005A      MK        co  1409.0 2018-10-13 21:00:00+00:00
# 1      Centar    MK005A      MK       no2    30.0 2018-10-13 21:00:00+00:00
# 2      Centar    MK005A      MK        o3    14.0 2018-10-13 21:00:00+00:00
# 3      Centar    MK005A      MK       so2    27.0 2018-10-13 21:00:00+00:00
# 4    Rasadnik   Goražde      BA        co   141.0 2018-09-08 07:00:00+00:00
# 5    Rasadnik   Goražde      BA        o3     8.0 2018-08-15 02:00:00+00:00
# 6    Rasadnik   Goražde      BA       so2    10.0 2018-09-08 07:00:00+00:00
# 7   IvanSedlo  Sarajevo      BA        o3    50.0 2018-10-13 21:00:00+00:00
# 8   IvanSedlo  Sarajevo      BA      pm10    86.0 2018-10-01 07:00:00+00:00
# 9   IvanSedlo  Sarajevo      BA       so2    13.0 2018-10-13 21:00:00+00:00
# 10     Ilidža  Sarajevo      BA       no2    32.0 2018-10-13 21:00:00+00:00
# 11     Ilidža  Sarajevo      BA        o3    14.0 2018-10-13 21:00:00+00:00
# 12     Ilidža  Sarajevo      BA      pm10    82.0 2018-10-13 21:00:00+00:00
# 13     Ilidža  Sarajevo      BA       so2    11.0 2018-10-13 21:00:00+00:00
# 14      Otoka  Sarajevo      BA       no2    57.0 2018-10-13 21:00:00+00:00
# 15      Otoka  Sarajevo      BA        o3     3.0 2018-10-13 21:00:00+00:00
# 16      Otoka  Sarajevo      BA      pm10    62.0 2018-10-13 21:00:00+00:00
    FROM `bigquery-public-data.openaq.global_air_quality`
    WHERE source_name = "Bosnia"
""")

# %%
results = query_job.result()
result = results.to_dataframe()
result
# Out:
#             location      city country pollutant   value  \
# 0           Rasadnik   Goražde      BA       no2    19.0
# 1           Rasadnik   Goražde      BA      pm10     2.0
# 2         Ivan Sedlo  Sarajevo      BA        co   566.0
# 3         Ivan Sedlo  Sarajevo      BA       no2     0.0
# 4   mobilna (Ilidža)  Sarajevo      BA        co   316.0
# 5              Otoka  Sarajevo      BA        co   267.0
# 6          Vijećnica  Sarajevo      BA        o3    19.0
# 7              Brist    Zenica      BA        co     0.0
# 8              Brist    Zenica      BA       no2    22.0
# 9            Harmani     Jajce      BA        co  1508.0
# 10           Harmani     Jajce      BA       so2    29.0
#
#                    timestamp   unit source_name  latitude  longitude  \
# 0  2018-03-22 23:00:00+00:00  µg/m³      Bosnia    43.661     18.977
# 1  2018-03-14 14:00:00+00:00  µg/m³      Bosnia    43.661     18.977
# 2  2016-11-27 11:00:00+00:00  µg/m³      Bosnia    43.715     18.036
# 3  2016-06-06 09:30:00+00:00  µg/m³      Bosnia    43.715     18.036
# 4  2016-11-27 11:00:00+00:00  µg/m³      Bosnia    43.830     18.311
# 5  2016-11-27 11:00:00+00:00  µg/m³      Bosnia    43.848     18.364
# 6  2017-02-13 13:00:00+00:00  µg/m³      Bosnia    43.859     18.435
# 7  2016-06-30 06:00:00+00:00  µg/m³      Bosnia    44.202     17.800
# 8  2017-10-25 21:00:00+00:00  µg/m³      Bosnia    44.202     17.800
# 9  2016-11-27 11:00:00+00:00  µg/m³      Bosnia    44.343     17.268
# 10 2018-03-23 00:00:00+00:00  µg/m³      Bosnia    44.343     17.268
#
#     averaged_over_in_hours
# 0                      1.0
# 1                      1.0
# 2                      1.0
# 3                      1.0
# 4                      1.0
# 5                      1.0
# 6                      1.0
# 7                      1.0
# 8                      1.0
# 9                      1.0
# 10                     1.0

# %% [markdown]
# ### At what time do sensors send data?

# %%
query_job = client.query("""
    SELECT DISTINCT timestamp
    FROM `bigquery-public-data.openaq.global_air_quality`
    WHERE source_name = "Bosnia_Tuzlanski" AND CAST(timestamp as date) = CAST("2020-01-19" as date)
""")

# %%
results = query_job.result()

# %%
results.to_dataframe()
# Out:
#                   timestamp
# 0 2020-01-19 18:00:00+00:00

# %% [markdown]
# After some further analysis I realized that I can obtain just the last two measurements, all other is deleted.

# %% [markdown]
# ### Let's get data from this day

# %%
query_job = client.query("""
    SELECT *
    FROM `bigquery-public-data.openaq.global_air_quality`
    WHERE source_name = "Bosnia_Tuzlanski" AND CAST(timestamp as date) = CAST("2020-01-19" as date)
    """)

# %%
results = query_job.result()
result = results.to_dataframe()

# %%
result
# Out:
#     location      city country pollutant   value                 timestamp  \
# 0   Živinice  Živinice      BA        co  3637.0 2020-01-19 18:00:00+00:00
# 1   Živinice  Živinice      BA       no2    31.4 2020-01-19 18:00:00+00:00
# 2   Živinice  Živinice      BA       so2   173.7 2020-01-19 18:00:00+00:00
# 3    Bukinje     Tuzla      BA        co  1680.0 2020-01-19 18:00:00+00:00
# 4    Bukinje     Tuzla      BA        o3     6.2 2020-01-19 18:00:00+00:00
# 5    Bukinje     Tuzla      BA      pm25    43.2 2020-01-19 18:00:00+00:00
# 6    Bukinje     Tuzla      BA       so2    38.8 2020-01-19 18:00:00+00:00
# 7        BKC     Tuzla      BA        co  2505.0 2020-01-19 18:00:00+00:00
# 8        BKC     Tuzla      BA       no2    27.7 2020-01-19 18:00:00+00:00
# 9        BKC     Tuzla      BA        o3     4.8 2020-01-19 18:00:00+00:00
# 10       BKC     Tuzla      BA       so2    36.9 2020-01-19 18:00:00+00:00
# 11   Lukavac   Lukavac      BA        co  2656.0 2020-01-19 18:00:00+00:00
# 12   Lukavac   Lukavac      BA       no2    28.0 2020-01-19 18:00:00+00:00
# 13   Lukavac   Lukavac      BA        o3     3.3 2020-01-19 18:00:00+00:00
# 14   Lukavac   Lukavac      BA      pm25    33.3 2020-01-19 18:00:00+00:00
# 15   Lukavac   Lukavac      BA       so2    17.8 2020-01-19 18:00:00+00:00
# 16     Skver     Tuzla      BA       no2    29.4 2020-01-19 18:00:00+00:00
# 17     Skver     Tuzla      BA        o3    15.0 2020-01-19 18:00:00+00:00
# 18     Skver     Tuzla      BA      pm25    44.1 2020-01-19 18:00:00+00:00
# 19     Skver     Tuzla      BA       so2    49.7 2020-01-19 18:00:00+00:00
#
#      unit       source_name   latitude  longitude  averaged_over_in_hours
# 0   µg/m³  Bosnia_Tuzlanski  44.453888  18.648333                     1.0
# 1   µg/m³  Bosnia_Tuzlanski  44.453888  18.648333                     1.0
# 2   µg/m³  Bosnia_Tuzlanski  44.453888  18.648333                     1.0
# 3   µg/m³  Bosnia_Tuzlanski  44.523613  18.600277                     1.0
# 4   µg/m³  Bosnia_Tuzlanski  44.523613  18.600277                     1.0
# 5   µg/m³  Bosnia_Tuzlanski  44.523613  18.600277                     1.0
# 6   µg/m³  Bosnia_Tuzlanski  44.523613  18.600277                     1.0
# 7   µg/m³  Bosnia_Tuzlanski  44.531944  18.654722                     1.0
# 8   µg/m³  Bosnia_Tuzlanski  44.531944  18.654722                     1.0
# 9   µg/m³  Bosnia_Tuzlanski  44.531944  18.654722                     1.0
# 10  µg/m³  Bosnia_Tuzlanski  44.531944  18.654722                     1.0
# 11  µg/m³  Bosnia_Tuzlanski  44.533302  18.534891                     1.0
# 12  µg/m³  Bosnia_Tuzlanski  44.533302  18.534891                     1.0
# 13  µg/m³  Bosnia_Tuzlanski  44.533302  18.534891                     1.0
# 14  µg/m³  Bosnia_Tuzlanski  44.533302  18.534891                     1.0
# 15  µg/m³  Bosnia_Tuzlanski  44.533302  18.534891                     1.0
# 16  µg/m³  Bosnia_Tuzlanski  44.540833  18.673334                     1.0
# 17  µg/m³  Bosnia_Tuzlanski  44.540833  18.673334                     1.0
# 18  µg/m³  Bosnia_Tuzlanski  44.540833  18.673334                     1.0
# 19  µg/m³  Bosnia_Tuzlanski  44.540833  18.673334                     1.0

# %%
query_job = client.query("""
    SELECT location, value
    FROM `bigquery-public-data.openaq.global_air_quality`
    WHERE source_name = "Bosnia_Tuzlanski" AND CAST(timestamp as date) = CAST("2020-01-19" as date) AND pollutant = "pm25"
    ORDER BY value DESC
    """)

# %%
pm25 = query_job.result()
df_pm25 = pm25.to_dataframe()

# %%
df_pm25
# Out:
#   location  value
# 0    Skver   44.1
# 1  Bukinje   43.2
# 2  Lukavac   33.3

# %%
import pandas as pd

result.to_csv("AirQuality.csv", index = False)

# %%
import pandas as pd

df = pd.read_csv("AirQuality.csv")
df
# Out:
#     location      city country pollutant   value                  timestamp  \
# 0   Živinice  Živinice      BA        co  3637.0  2020-01-19 18:00:00+00:00
# 1   Živinice  Živinice      BA       no2    31.4  2020-01-19 18:00:00+00:00
# 2   Živinice  Živinice      BA       so2   173.7  2020-01-19 18:00:00+00:00
# 3    Bukinje     Tuzla      BA        co  1680.0  2020-01-19 18:00:00+00:00
# 4    Bukinje     Tuzla      BA        o3     6.2  2020-01-19 18:00:00+00:00
# 5    Bukinje     Tuzla      BA      pm25    43.2  2020-01-19 18:00:00+00:00
# 6    Bukinje     Tuzla      BA       so2    38.8  2020-01-19 18:00:00+00:00
# 7        BKC     Tuzla      BA        co  2505.0  2020-01-19 18:00:00+00:00
# 8        BKC     Tuzla      BA       no2    27.7  2020-01-19 18:00:00+00:00
# 9        BKC     Tuzla      BA        o3     4.8  2020-01-19 18:00:00+00:00
# 10       BKC     Tuzla      BA       so2    36.9  2020-01-19 18:00:00+00:00
# 11   Lukavac   Lukavac      BA        co  2656.0  2020-01-19 18:00:00+00:00
# 12   Lukavac   Lukavac      BA       no2    28.0  2020-01-19 18:00:00+00:00
# 13   Lukavac   Lukavac      BA        o3     3.3  2020-01-19 18:00:00+00:00
# 14   Lukavac   Lukavac      BA      pm25    33.3  2020-01-19 18:00:00+00:00
# 15   Lukavac   Lukavac      BA       so2    17.8  2020-01-19 18:00:00+00:00
# 16     Skver     Tuzla      BA       no2    29.4  2020-01-19 18:00:00+00:00
# 17     Skver     Tuzla      BA        o3    15.0  2020-01-19 18:00:00+00:00
# 18     Skver     Tuzla      BA      pm25    44.1  2020-01-19 18:00:00+00:00
# 19     Skver     Tuzla      BA       so2    49.7  2020-01-19 18:00:00+00:00
#
#      unit       source_name   latitude  longitude  averaged_over_in_hours
# 0   µg/m³  Bosnia_Tuzlanski  44.453888  18.648333                     1.0
# 1   µg/m³  Bosnia_Tuzlanski  44.453888  18.648333                     1.0
# 2   µg/m³  Bosnia_Tuzlanski  44.453888  18.648333                     1.0
# 3   µg/m³  Bosnia_Tuzlanski  44.523613  18.600277                     1.0
# 4   µg/m³  Bosnia_Tuzlanski  44.523613  18.600277                     1.0
# 5   µg/m³  Bosnia_Tuzlanski  44.523613  18.600277                     1.0
# 6   µg/m³  Bosnia_Tuzlanski  44.523613  18.600277                     1.0
# 7   µg/m³  Bosnia_Tuzlanski  44.531944  18.654722                     1.0
# 8   µg/m³  Bosnia_Tuzlanski  44.531944  18.654722                     1.0
# 9   µg/m³  Bosnia_Tuzlanski  44.531944  18.654722                     1.0
# 10  µg/m³  Bosnia_Tuzlanski  44.531944  18.654722                     1.0
# 11  µg/m³  Bosnia_Tuzlanski  44.533302  18.534891                     1.0
# 12  µg/m³  Bosnia_Tuzlanski  44.533302  18.534891                     1.0
# 13  µg/m³  Bosnia_Tuzlanski  44.533302  18.534891                     1.0
# 14  µg/m³  Bosnia_Tuzlanski  44.533302  18.534891                     1.0
# 15  µg/m³  Bosnia_Tuzlanski  44.533302  18.534891                     1.0
# 16  µg/m³  Bosnia_Tuzlanski  44.540833  18.673334                     1.0
# 17  µg/m³  Bosnia_Tuzlanski  44.540833  18.673334                     1.0
# 18  µg/m³  Bosnia_Tuzlanski  44.540833  18.673334                     1.0
# 19  µg/m³  Bosnia_Tuzlanski  44.540833  18.673334                     1.0

# %% [markdown]
# ## Plot the data!

# %%
import gmaps

gmaps.figure(center = (44.53842, 18.66709), zoom_level = 1)
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### I planned to plot that data on a map, but as I did not have an API key (you have to buy it) I decided to make some basic plots.

# %%
import matplotlib.pyplot as plt

plt.bar(df_pm25.location, df_pm25.value, align='center', color = list('rgbkymc'))
plt.ylabel("Value")
plt.title("Tuzla pm2.5 particles")
# Out:
# Text(0.5, 1.0, 'Tuzla pm2.5 particles')

# %% [markdown]
# ### Same result with two different techniques

# %%
dataset = df[df["pollutant"] == "pm25"]

# %%
dataset = dataset.sort_values(by = "value", ascending = False)

# %%
plt.bar(dataset.location, dataset.value, align = "center", color = list('rgbcmyk'))
plt.ylabel("Value")
plt.title("Tuzla pm2.5 particles for 1/19/2020")
# Out:
# Text(0.5, 1.0, 'Tuzla pm2.5 particles for 1/19/2020')

# %%
df["pollutant"].value_counts()
# Out:
# so2     5
# no2     4
# o3      4
# co      4
# pm25    3
# Name: pollutant, dtype: int64

# %%
so2 = df[df["pollutant"] == "so2"]

# %%
so2 = so2.sort_values(by = "value", ascending = False)

# %%
plt.bar(so2["location"], so2.value, color = list("cmyk"), align = "center")
plt.title("Tuzla SO2 particles for 1/19/2020")
plt.ylabel("value [ug/m3]")
# Out:
# Text(0, 0.5, 'value [ug/m3]')

# %%
no2 = df[df["pollutant"] == "no2"]

# %%
no2 = no2.sort_values(by = "value", ascending = False)

# %%
plt.bar(no2["location"], no2.value, color = list("cmyk"), align = "center")
plt.title("Tuzla NO2 particles for 1/19/2020")
plt.ylabel("value [ug/m3]")
# Out:
# Text(0, 0.5, 'value [ug/m3]')

# %%
co = df[df["pollutant"] == "co"]

# %%
co = co.sort_values(by = "value", ascending = False)

# %%
plt.bar(co["location"], co.value, color = list("cmyk"), align = "center")
plt.title("Tuzla CO particles for 1/19/2020")
plt.ylabel("value [ug/m3]")
# Out:
# Text(0, 0.5, 'value [ug/m3]')

# %%
o3 = df[df["pollutant"] == "o3"]

# %%
o3 = o3.sort_values(by = "value", ascending = False)

# %%
plt.bar(o3["location"], o3.value, color = list("cmyk"), align = "center")
plt.title("Tuzla O3 particles for 1/19/2020")

plt.ylabel("value [ug/m3]")
# Out:
# Text(0, 0.5, 'value [ug/m3]')

# %%
import seaborn as sns

sns.barplot(x = o3.value, y = o3.location)
